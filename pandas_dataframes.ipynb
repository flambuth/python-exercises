# %%
from pydataset import data

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(123)

# %%
students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# %%
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

# %%
df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %%
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
# Create a column named passing_english that indicates whether each student has a passing grade in reading.
df["passing_english"] = df['english'] > 69

# %%
# Sort the english grades by the passing_english column. How are duplicates handled?
df.sort_values(by=["passing_english","name"])
# Duplicates are sorted by the row-index in ascending order
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
# Sort the english grades first by passing_english and then by student name. All the students
# that are failing english should be first, and within the students that are failing english 
# they should be ordered alphabetically. The same should be true for the students passing 
# english. (Hint: you can pass a list to the .sort_values method)
df.sort_values(by=["passing_english","name"])
# Out:
#        name  math  english  reading  passing_english
# 11     Alan    92       62       72            False
# 8    Albert    92       62       87            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True
# 1      Jane    88       79       67             True
# 5      John    79       76       93             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 2     Suzie    94       74       95             True

# %%
# Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.
df.sort_values(by=["passing_english","english"])
# Out:
#        name  math  english  reading  passing_english
# 8    Albert    92       62       87            False
# 11     Alan    92       62       72            False
# 7     Marie    93       63       90            False
# 6    Thomas    82       64       81            False
# 2     Suzie    94       74       95             True
# 5      John    79       76       93             True
# 1      Jane    88       79       67             True
# 9   Richard    69       80       94             True
# 0     Sally    62       85       80             True
# 4       Ada    77       92       98             True
# 3     Billy    98       96       88             True
# 10    Isaac    92       99       93             True

# %%
df
# Out:
#        name  math  english  reading  passing_english
# 0     Sally    62       85       80             True
# 1      Jane    88       79       67             True
# 2     Suzie    94       74       95             True
# 3     Billy    98       96       88             True
# 4       Ada    77       92       98             True
# 5      John    79       76       93             True
# 6    Thomas    82       64       81            False
# 7     Marie    93       63       90            False
# 8    Albert    92       62       87            False
# 9   Richard    69       80       94             True
# 10    Isaac    92       99       93             True
# 11     Alan    92       62       72            False

# %%
# Calculate each students overall grade and add it as a column on the dataframe. 
# The overall grade is the average of the math, english, and reading grades.

#this sums all the values in each row.
#the sum collapses all the fields into one field per row.
#I'll add this as a column
df.sum(axis=1)
# Out:
# 0     228.0
# 1     235.0
# 2     264.0
# 3     283.0
# 4     268.0
# 5     249.0
# 6     227.0
# 7     246.0
# 8     241.0
# 9     244.0
# 10    285.0
# 11    226.0
# dtype: float64

# %%
df['overall_grade'] = df.sum(axis=1)

# %%
df.sort_values(by='overall_grade')
# Out:
#        name  math  english  reading  passing_english  overall_grade
# 11     Alan    92       62       72            False          226.0
# 6    Thomas    82       64       81            False          227.0
# 0     Sally    62       85       80             True          228.0
# 1      Jane    88       79       67             True          235.0
# 8    Albert    92       62       87            False          241.0
# 9   Richard    69       80       94             True          244.0
# 7     Marie    93       63       90            False          246.0
# 5      John    79       76       93             True          249.0
# 2     Suzie    94       74       95             True          264.0
# 4       Ada    77       92       98             True          268.0
# 3     Billy    98       96       88             True          283.0
# 10    Isaac    92       99       93             True          285.0

# %%
mpg = data('mpg')

# %%
# 2
# How many rows and columns are there?
print(f"There are {mpg.shape[0]} rows and {mpg.shape[1]} columns.")
# Out:
# There are 234 rows and 11 columns.

# %%
# What are the data types of each column?
mpg.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %%
#messing around to see the dtypes are a Series object. 
mpg.dtypes[:'year']
mpg.dtypes.iloc[:4]
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# dtype: object

# %%
mpg.dtypes[:'year']
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# dtype: object

# %%
# Summarize the dataframe with .info and .describe
# mpg.describe
# mpg.info

# %%
# Rename the cty column to city.
mpg = mpg.rename(columns={"cty": "city"})
mpg.head(10)
# Out:
#    manufacturer       model  displ  year  cyl       trans drv  city  highway  \
# 1          audi          a4    1.8  1999    4    auto(l5)   f    18       29
# 2          audi          a4    1.8  1999    4  manual(m5)   f    21       29
# 3          audi          a4    2.0  2008    4  manual(m6)   f    20       31
# 4          audi          a4    2.0  2008    4    auto(av)   f    21       30
# 5          audi          a4    2.8  1999    6    auto(l5)   f    16       26
# 6          audi          a4    2.8  1999    6  manual(m5)   f    18       26
# 7          audi          a4    3.1  2008    6    auto(av)   f    18       27
# 8          audi  a4 quattro    1.8  1999    4  manual(m5)   4    18       26
# 9          audi  a4 quattro    1.8  1999    4    auto(l5)   4    16       25
# 10         audi  a4 quattro    2.0  2008    4  manual(m6)   4    20       28
#
#    fl    class
# 1   p  compact
# 2   p  compact
# 3   p  compact
# 4   p  compact
# 5   p  compact
# 6   p  compact
# ...

# %%
# Rename the hwy column to highway.
mpg = mpg.rename(columns={"hwy": "highway"})
# I could've done that on the last cell if I knew I was gonna rename two columns. =(

# %%
# Do any cars have better city mileage than highway mileage?
mpg[mpg['city'] > mpg['highway']]
#That boolean mask returned no rows. So I'd say no.
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class]
# Index: []

# %%
# Create a column named mileage_difference this column should contain the difference 
# between highway and city mileage for each car.
mpg['mileage_difference'] = mpg['highway'] - mpg['city']
mpg.sort_values(by='mileage_difference', ascending=False)
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 107        honda                   civic    1.8  2008    4    auto(l5)   f
# 223   volkswagen              new beetle    1.9  1999    4    auto(l4)   f
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 229   volkswagen                  passat    1.8  1999    4    auto(l5)   f
# 36     chevrolet                  malibu    3.5  2008    6    auto(l4)   f
# 213   volkswagen                   jetta    1.9  1999    4  manual(m5)   f
# 106        honda                   civic    1.8  2008    4    auto(l5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 24     chevrolet                corvette    5.7  1999    8  manual(m6)   r
# 183       toyota                   camry    2.4  2008    4    auto(l5)   f
# 232   volkswagen                  passat    2.8  1999    6    auto(l5)   f
# ...

# %%
# Which car (or cars) has the highest mileage difference?

#Sorted the cars by the indicated column, from greatest to least, and just the top 5
mpg.sort_values(by="mileage_difference", ascending=False).head(5)
# Out:
#     manufacturer       model  displ  year  cyl     trans drv  city  highway  \
# 107        honda       civic    1.8  2008    4  auto(l5)   f    24       36
# 223   volkswagen  new beetle    1.9  1999    4  auto(l4)   f    29       41
# 1           audi          a4    1.8  1999    4  auto(l5)   f    18       29
# 229   volkswagen      passat    1.8  1999    4  auto(l5)   f    18       29
# 36     chevrolet      malibu    3.5  2008    6  auto(l4)   f    18       29
#
#     fl       class  mileage_difference
# 107  c  subcompact                  12
# 223  d  subcompact                  12
# 1    p     compact                  11
# 229  p     midsize                  11
# 36   r     midsize                  11

# %%
# Which compact class car has the lowest highway mileage? 
mpg[mpg['class'] == 'compact'].sort_values(by='highway').head(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_difference
# 220  compact                   7

# %%
# The best?
mpg[mpg['class'] == 'compact'].sort_values(by='highway', ascending=False).head(1)
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  mileage_difference
# 213  compact                  11

# %%
(mpg['city'] + mpg['highway'])/2
# Out:
# 1      23.5
# 2      25.0
# 3      25.5
# 4      25.5
# 5      21.0
# 6      22.0
# 7      22.5
# 8      22.0
# 9      20.5
# 10     24.0
# 11     23.0
# 12     20.0
# 13     21.0
# 14     21.0
# 15     20.0
# 16     19.5
# 17     21.0
# 18     19.5
# 19     17.0
# 20     13.0
# 21     17.0
# 22     15.0
# 23     14.5
# 24     21.0
# 25     19.0
# 26     21.0
# 27     20.0
# 28     19.5
# 29     16.5
# 30     12.5
# 31     13.0
# 32     15.5
# 33     23.0
# 34     26.0
# 35     22.0
# 36     23.5
# 37     21.5
# 38     21.0
# 39     20.5
# 40     19.0
# 41     19.0
# 42     20.5
# 43     20.5
# 44     14.0
# 45     18.5
# 46     18.0
# 47     19.5
# 48     19.5
# 49     17.0
# 50     16.0
# 51     15.0
# 52     15.5
# 53     16.5
# 54     16.5
# 55     10.5
# 56     14.0
# 57     13.0
# 58     15.0
# 59     15.0
# 60     10.5
# 61     15.0
# 62     13.5
# 63     15.5
# 64     13.0
# 65     14.0
# 66     10.5
# 67     15.0
# 68     15.0
# 69     14.0
# 70     10.5
# 71     13.0
# ...

# %%
# Create a column named average_mileage that is the mean of the city and highway mileage.
mpg['average_mileage'] = (mpg['city'] + mpg['highway']) / 2
mpg.sort_values(by='average_mileage', ascending=False)
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 222   volkswagen              new beetle    1.9  1999    4  manual(m5)   f
# 213   volkswagen                   jetta    1.9  1999    4  manual(m5)   f
# 223   volkswagen              new beetle    1.9  1999    4    auto(l4)   f
# 197       toyota                 corolla    1.8  2008    4  manual(m5)   f
# 196       toyota                 corolla    1.8  1999    4  manual(m5)   f
# 106        honda                   civic    1.8  2008    4    auto(l5)   f
# 100        honda                   civic    1.6  1999    4  manual(m5)   f
# 198       toyota                 corolla    1.8  2008    4    auto(l4)   f
# 105        honda                   civic    1.8  2008    4  manual(m5)   f
# 107        honda                   civic    1.8  2008    4    auto(l5)   f
# 102        honda                   civic    1.6  1999    4  manual(m5)   f
# ...

# %%
# Which dodge car has the best average mileage? 
mpg[mpg['manufacturer'] == 'dodge'].sort_values(by="average_mileage", ascending=False).head(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  mileage_difference  average_mileage
# 38  r  minivan                   6             30.0

# %%
# The worst?
mpg[mpg['manufacturer'] == 'dodge'].sort_values(by="average_mileage").head(1)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  mileage_difference  average_mileage
# 70       12  e  pickup                   3             10.5

# %%
#3
#mammals dataset

# %%
mammals = data('Mammals')

# %%
# How many rows and columns are there?
mammals.shape
print(f"There are {mammals.shape[0]} rows and {mammals.shape[1]} columns.")
# Out:
# There are 107 rows and 4 columns.

# %%
# What are the data types?
mammals.dtypes
# Out:
# weight      float64
# speed       float64
# hoppers        bool
# specials       bool
# dtype: object

# %%
# Summarize the dataframe with .info and .describe
mammals.info
mammals.describe

# %%
# What is the the weight of the fastest animal?
fastest_animal_weight = mammals.sort_values(by='speed', ascending=False).head(1)['weight']

# %%
fastest_animal_weight.iloc[0]
# Out:
# 55.0

# %%
mammals.loc[53]['weight']
# Out:
# 55.0

# %%
print(f"The fastest animal has the weight of {mammals.loc[53]['weight']}")
# Out:
# The fastest animal has the weight of 55.0

# %%
# What is the overal percentage of specials?
mammals[mammals['specials'] ==  True]
# Out:
#      weight  speed  hoppers  specials
# 10   3800.0   25.0    False      True
# 59     12.0   24.0    False      True
# 60     11.0   30.0    False      True
# 65      5.0   27.0    False      True
# 66      3.0   16.0    False      True
# 68     70.0   40.0    False      True
# 69     13.0   37.0    False      True
# 70      9.0    3.2    False      True
# 105     5.0    7.4    False      True
# 107     4.0    1.6    False      True

# %%
#boolean mask skimming out the mammals that have true in their specials column
len(mammals[mammals['specials'] ==  True])
# Out:
# 10

# %%
#All the the animals. So the specials will be a percentage of this total.
len(mammals)
# Out:
# 107

# %%
#10/107 essentially
special_percent = str(len(mammals[mammals['specials'] ==  True]) / len(mammals))

# %%
#Lets make a nice print statement.
print(f"The percentage of animals that are special is {special_percent[:5]}%.")
# Out:
# The percentage of animals that are special is 0.093%.

# %%
# How many animals are hoppers that are above the median speed? What percentage is this?

# %%
#the mammals who are hoppers
mammals[mammals['hoppers'] == True]
# Out:
#      weight  speed  hoppers  specials
# 82    0.056   21.0     True     False
# 85    0.035   32.0     True     False
# 86    0.035   14.0     True     False
# 96    4.600   64.0     True     False
# 97    4.400   72.0     True     False
# 98    4.000   72.0     True     False
# 99    3.500   56.0     True     False
# 100   2.000   64.0     True     False
# 101   1.900   56.0     True     False
# 102   1.500   50.0     True     False
# 103   1.500   40.0     True     False

# %%
#This is the median of the speed column
#This is done by calling all rows with :, and then calling for just the speed column by its
#explicit index, hence the .loc method. This selection is a series, which has a median method.
type(mammals.loc[:,"speed"])
speed_median = mammals.loc[:,"speed"].median()

# %%
#This is a less comlext way of getting to the speed column. Argh....
mammals['speed'].median()
speed_median
# Out:
# 48.0

# %%
#Animals that are faster than the median.
mammals[(mammals['speed'] > speed_median) & (mammals['hoppers'] == True)]
# Out:
#      weight  speed  hoppers  specials
# 96      4.6   64.0     True     False
# 97      4.4   72.0     True     False
# 98      4.0   72.0     True     False
# 99      3.5   56.0     True     False
# 100     2.0   64.0     True     False
# 101     1.9   56.0     True     False
# 102     1.5   50.0     True     False

# %%
print(f"{7/len(mammals)} is the percentage of hoppers who are faster than the median.")
# Out:
# 0.06542056074766354 is the percentage of hoppers who are faster than the median.
